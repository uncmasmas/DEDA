# %% [markdown]
# ## Analyzing the possible submission status in introalg-2c-2017 database

# %% [markdown]
# In this notebook we analyse the possible values that the submssion status can take. We also calculate how frequent they are in the introalg-2c-2017 dataset

# %% [markdown]
# ## Set up
# First of all we load the libraries that we need for the code below. **Json** is the format in which the database is stored. **Pandas** is a python library for handling databases in the memory of the computer. Pandas store the data in structures called **dataframes**. **Os** is a library used to gain portability to other operating systems, in this way the notebook will work in Ubuntu, Windows, etc.

# %%
import json
import pandas as pd
import os

# %% [markdown]
# ## Load database
#
# LB: Avoid using comments in the text as you do below. Comments tend to be short and not human friendly :). Put a Markdown cell as this one before each cell of code and explain what the code below it does. Replace what I wrote here by an explanation of what is going on below. Explain what it means to expand and print some sample submission so that we see the shape of the data.

# %%
#Load Dataset  
dataset_home = 'datasets'
json_file = open(os.path.join(dataset_home, '2017-2c-introalgo-2c-2017.json'), encoding='utf8')
json_data = json.load(json_file)

#train_df = pd.io.json.json_normalize(json_data) #LB: this variable is never used, do not define variables that you do not use

#Expand and show the first submissions in the Dataframe 
submissions = pd.io.json.json_normalize(json_data, record_path='submissions')
submissions.columns

# %%
results = set([])
#calculate possible status value for submissions
for elem in submissions.status:
    results.add(elem)
print("Submissions status {}".format(results))

# %%
#count amount of submmissions
total_amount_submissions = submissions.shape[0]
total_amount_submissions

# %%
#Obtain frequency of submission grouped by status
submissions_grouped = submissions.groupby(['status']).size()
metrics = {}
metrics = submissions_grouped / total_amount_submissions
metrics

# %% [markdown]
# # Metrics in courses
# Calculate status distribution in all submissions in assignments

# %%
dataset_home = 'datasets/courses/'

df = pd.DataFrame(
    columns=['course', 'submission_amount', 'errored', 'failed', 'passed', 'passed_with_warnings'])

metrics_list = []
for course in os.listdir('datasets/courses/'):
    json_file = open(os.path.join(dataset_home, course), encoding='utf8')
    json_data = json.load(json_file)
    submissions = pd.io.json.json_normalize(json_data, record_path='submissions')
    submissions = submissions[~(submissions['status'] == 'aborted')]
    submissions = submissions[~(submissions['status'] == 'pending')]
    submissions = submissions[~(submissions['status'] == 'manual_evaluation_pending')]
    total_amount_submissions = submissions.shape[0]
    submissions_grouped = submissions.groupby(['status']).size()
    metrics = {}
    metrics = submissions_grouped / total_amount_submissions
    metrics['course'] = str(course)
    metrics['submission_amount'] = total_amount_submissions
    df = df.append(metrics, ignore_index=True)

# %%
mean = (df[["errored", "failed", "passed", "passed_with_warnings"]].multiply(df["submission_amount"], axis="index")).sum()/(df['submission_amount']).sum()

# %%
mean['course'] = 'Promedios'
mean['submission_amount'] = df['submission_amount'].sum()
df.loc[len(df)] = mean

# %%
df
# Out:
#                                                 course submission_amount  \
# 0                            pdep-utn_2016-noc-ju.json             52696
# 1                      alcal-prog3_2017-ayudantes.json               467
# 2                         pdep-utn-frd_2017-unico.json              5296
# 3                       secundaria.sanluis_2018-2.json              4760
# 4                             inpr-unq_2016-2s-c1.json              9198
# 5                             icade_0616-ikd62016.json              1286
# 6                                      smartedu__.json                37
# 7                            inpr-sarmiento_otros.json                 3
# 8         introalgo-unc_2016-2c-introalgo-2c-2016.json             22289
# 9                      alcal-prog1_2018-4b-grupo2.json               817
# 10                      secundaria.sanluis_2018-4.json              9282
# 11                          suetra_2017-comision2.json              2738
# 12                               central_2016-200.json                 1
# 13                           pdep-utn_2016-noc-mi.json             15489
# 14                                      central__.json                 1
# 15                            obj3-unq_2016-2c-c1.json              1543
# 16                   primaria.sanluis_2018-4grado.json              5746
# 17                          orga-unq_2016-2c-com5.json              1285
# 18                      secundaria.sanluis_2018-1.json              2372
# 19                  fundacionhemofilia_2018-k2018.json              2158
# 20                   salvadorsoreda_2016-3ºa-2016.json               621
# 21                            inpr-unq_2016-2s-c3.json              5334
# 22                     alcal-prog1_2018-4b-grupo1.json               570
# 23                                      sanluis_1.json               390
# 24                  pdep-utn_pdep-utn-2016-tar-sa.json             12127
# 25                                   cgp_2018-3ro.json               759
# 26                             turte-uvq_2016-001.json                 9
# 27                                      objetos__.json              1030
# 28                 pdep-utn_2016-miercoles-manana.json             26395
# 29                           pdp-unsam_lunes-2016.json             12856
# ..                                                 ...               ...
# 93                          algo2-undav_2017-2c-1.json              7323
# 94                      colegioloscedros_2016-lc6.json              2436
# 95                                tutorias_2016-1.json               930
# 96   introalgo-unc-1c-2017_2017-1c-introalgo-1c-201...              3144
# 97                            inpr-unq_2016-2s-c2.json              4770
# 98                  pdep-utn_pdep-utn-2016-noc-ma.json              9209
# 99                                 dds_2018-k3003.json              4703
# 100                         alcal_2016-pendientes.json               127
# 101                     algo1-unsam_2017-1c-unico.json              1472
# 102                          sanluis_jovenes-2018.json              3537
# 103                                    cfp_2017-2.json               931
# 104                  primaria.sanluis_2018-5grado.json              5317
# 105                                     sanluis__.json               649
# 106                         alcal_2016-4b-grupo-2.json              1784
# 107                   pdep-utn_viernes-noche-2016.json             29655
# 108             orga-unq_2016-2c-com3-rosito-pari.json               242
# 109                                  ngs_2018-4to.json               519
# 110                           staging_2017-kk2017.json               611
# 111                      fundacionleon_2017-a2017.json                10
# 112                     secundaria.sanluis_2018-3.json              5451
# 113                         amigos_2016-dilorenzo.json               707
# 114               pdep-utn_pdep-utn-2016-man-ju-2.json             24067
# 115                  br.digitalhouse_2018-prework.json             36146
# 116                             english_2016-demo.json               110
# 117                                dds_2018-k3053.json              5787
# 118                                dds_2018-k3153.json              3334
# 119                         obj3-unq_2017-1c-obj3.json              1164
# 120                     alcal-prog3_2017-prog3-g2.json              1715
# 121                         suetra_2017-comision1.json              3505
# 122                                          Promedios            919831
#
#       errored    failed    passed  passed_with_warnings
# 0    0.141870  0.557101  0.262164              0.038864
# 1    0.205567  0.537473  0.256959                   NaN
