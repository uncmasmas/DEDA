# %% [markdown]
# # Haskell Failed Submissions Analysis

# %% [markdown]
# In this notebook we analyse the haskell submissions done by no registered users in Mumuki.io. The main objective is train a ML model that will be able to predict feedback for submissions.

# %% [markdown]
# # Set Up
# First of all we load the libraries that we need for the code below. **Json** is the format in which the database is stored. **Pandas** is a python library for handling databases in the memory of the computer. **Pandas** store the data in structures called dataframes. **Os** is a library used to gain portability to other operating systems, in this way the notebook will work in Ubuntu, Windows, etc. **Scikit Learn** python main library for machine learning. **Sklearn_pandas** provides a bridge between Scikit-Learn's machine learning methods and pandas-style Data Frames.

# %%
import pandas as pd
import json
import os
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn_pandas import DataFrameMapper

# %% [markdown]
# # Load Database
# Load only haskell submission divided by excercise. Loading the dataset in this way allows us to take a subset of exercises to ensure that in the training/test set there are samples of all the exercises. (To be implemented) By the moment we are using train_test_split function provided by scikit learn.

# %%
dataset_home = "datasets/haskell"
files = os.listdir(dataset_home)
submissions = pd.DataFrame()
for file in files:
    json_file = open(os.path.join(dataset_home, file), encoding='utf8')
    json_data = json.load(json_file)
    submissions = submissions.append(pd.io.json.json_normalize(json_data), ignore_index=True)

# %% [markdown]
# # Clean Dataset
# Remove submissions with blank content which is the solution written by the user.
# Remove submissions with status aborted or pending because those submissions are not evaluated due to net problems.

# %%
submissions = submissions[submissions['content'] != ""]
submissions = submissions[~submissions['content'].isnull()]
submissions = submissions[~(submissions['status'] == 'aborted')]
submissions = submissions[~(submissions['status'] == 'pending')]
#Improve it
submissions['result'] =  submissions.apply(
    lambda x : str(x.test_results) if x.status == 'failed' else (
        str(x.expectation_results) if x.status == 'passed_with_warnings' else('passed' if x.status == 'passed' else x.result)), axis=1)

# %% [markdown]
# # Narrow dataset
# Only use columns that provides important information.

# %%
X = submissions[['guide.slug', 'guide.language.name', 'content']]
Y = submissions['result']

# %%
X
# Out:
#                                                guide.slug guide.language.name  \
# 0       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 1       pdep-utn/mumuki-guia-funcional-practica-listas...             haskell
# 2       pdep-utn/mumuki-guia-funcional-practica-listas...             haskell
# 3       pdep-utn/mumuki-guia-funcional-practica-listas...             haskell
# 4       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 5       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 6       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 7       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 8       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 9       pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 10      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 11      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 12      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 13      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 14      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 15      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 16      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 17      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 18      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 19      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 20      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 21      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 22      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 23      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 24      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 25      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 26      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 27      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# 28      pdep-utn/mumuki-guia-funcional-practica-listas...             haskell
# 29      pdep-utn/mumuki-guia-funcional-practica-expres...             haskell
# ...                                                   ...                 ...
# 496404  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496405  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496406  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496407  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496408  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496409  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496410  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496411  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496412  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496413  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496414  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496415  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496416  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496417  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496418  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496419  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496420  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496421  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496422  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496423  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496424  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496425  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496426  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496427  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496428  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496429  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496430  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496431  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496432  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
# 496433  pdep-utn/mumuki-guia-funcional-funciones-parti...             haskell
#
#                                                   content
# 0         intersectar l1 l2 = filter (\x -> elem x l2) l1
# 1                             intersect xs ys = map id xs
# 2                           intersectar xs ys = map id xs
# 3             intersectar xs ys = [ x | x<-xs, elem x ys]
# 4       intersectar lista1 lista2 = filter (\x -> elem...
# 5       intersectar (x:xs) (y:ys) = filter (\x,y -> x ...
# 6            intersectar l1 l2 = filter (\x y -> x == y)
# 7       intersectar l1 l2 = \r\n    filter (\x y -> he...
# 8       intersectar l1 l2 = \r\n    filter (\x y -> x ...
# 9       intersectar l1 l2 = \r\n    filter (\x -> x ==...
# 10      intersectar l1 l2 = \r\n    filter (\x -> x ==...
# 11      intersectar l1 l2 = \r\n    filter (\x -> elem...
# 12      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 13      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 14      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 15      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 16      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 17      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 18      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 19      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 20      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 21      intersectar :: [a] -> [a] -> [a]\r\n\r\n\r\nin...
# 22                       intersectar = \x y-> filter x y
# 23          intersectar l1 l2 = filter (\x -> elem l2) l1
# 24           intersectar l1 l2 = filter (\x -> elem x) l1
# 25      intersectar l1 l2 = filter (\x -> intersect x) l1
# 26      intersectar l1 l2 = filter (\x -> intersect x ...
# 27        intersectar l1 l2 = filter (\x -> elem x l2) l1
# 28      intersectar xs ys = \r\n    [x | x <- xs, y <-...
# 29              intersectar l1 l2 = filter (\x -> x==) l1
# ...                                                   ...
# 496404  minimoEntre valor1 valor2 | valor1 > valor2 = ...
# 496405  minimoEntre x y | x <= y = x\r\n              ...
# 496406  minimoEntre numero1 numero2 | numero1 >= numer...
# 496407  minimoEntre numero1 numero2 | numero1 >= numer...
# 496408  minimoEntre numero1 numero2 | numero1 >= numer...
# 496409  minimoEntre numero1 numero2 | numero1 /= numer...
# 496410  minimoEntre numero1 numero2 | numero1 /= numer...
# 496411  minimoEntre numero1 numero2 | numero1 /= numer...
# 496412  minimoEntre num1 num2  | num1 >= num2 = num1\r...
# 496413  minimoEntre num1 num2  | num1 >= num2 = num2\r...
# 496414  minimoEntre num1 num2\r\n  |num1>num2=num1\r\n...
# 496415  minimoEntre num1 num2\r\n  | num1>num2=num2\r\...
# 496416  minimoEntre num1 num2\r\n  | num1>num2=num2\r\...
# 496417  minimoEntre a b | a>=b =b\r\n                |...
# 496418  minimoEntre a b | a>=b =a\r\n                |...
# 496419  minimoEntre a b | a>=b =b\r\n                |...
# 496420  minimoEntre num1 num2 | num1 >= num2 = num1\r\...
# 496421  minimoEntre num1 num2 | num1 >= num2 = num1\r\...
# 496422  minimoEntre num1 num2 | num1 >= num2 = num1\r\...
# 496423  minimoEntre num1 num2 | num1 <= num2 = num1\r\...
# 496424  minimoEntre x y | x <= y = x\r\n              ...
# 496425  minimoEntre x y | x <= y = x\r\n              ...
# 496426  minimoEntre num1 num2 |num1 <= num2 =num1\r\n ...
# 496427  minimoEntre num1 num2 |num1 <= num2 =num1\r\n ...
# 496428  minimoEntre numero1 numero2 \r\n | numero1 < n...
# 496429  minimoEntre numero1 numero2 \r\n | numero1 < n...
# 496430  minimoEntre a b | a<=b = a\r\n                ...
# 496431  minimoEntre x y | x < y = x\r\n               ...
# 496432    minimoEntre x y\r\n  |x<y = x\r\n  |otherwise y
# 496433   minimoEntre x y\r\n  |x<y = x\r\n  |otherwise= y
#
# [467385 rows x 3 columns]

# %%
Y
# Out:
# 0                                                    passed
# 1         \n/tmp/mumuki.compile20160726-25582-6b7u07.hs:...
# 2         [{'title': 'intersectar intersectar [1, 2, 3, ...
# 3         [{'binding': 'intersect', 'inspection': 'HasCo...
# 4                                                    passed
# 5         \n/tmp/mumuki.compile20160728-3796-1atis45.hs:...
# 6         [{'title': 'intersectar intersectar [1, 2, 3, ...
# 7         [{'title': 'intersectar intersectar [1, 2, 3, ...
# 8         [{'title': 'intersectar intersectar [1, 2, 3, ...
# 9         [{'title': 'intersectar intersectar [1, 2, 3, ...
# 10        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 11                                                   passed
# 12        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 13        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 14        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 15        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 16        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 17        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 18        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 19        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 20        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 21        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 22        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 23        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 24        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 25        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 26        [{'title': 'intersectar intersectar [1, 2, 3, ...
# 27                                                   passed
# 28                                                   passed
# 29        \n/tmp/mumuki.compile20160806-11809-1zqr59.hs:...
#                                 ...
# 496404                                               passed
# 496405                                               passed
# 496406                                               passed
# 496407    \nsolucion.hs:25:1:\n    parse error on input ...
# 496408                                               passed
# 496409    \nsolucion.hs:24:85:\n    Not in scope: ‘nuner...
# 496410    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496411                                               passed
# 496412    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496413                                               passed
# 496414    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496415    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496416                                               passed
# 496417    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496418    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496419                                               passed
# 496420    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496421    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496422    [{'title': 'minimoEntre 4 y 8 es 4', 'status':...
# 496423                                               passed
# 496424    \nsolucion.hs:27:1:\n    parse error (possibly...
# 496425                                               passed
# 496426    \nsolucion.hs:27:1:\n    parse error (possibly...
# 496427                                               passed
# 496428    \nsolucion.hs:27:3:\n    Not in scope: ‘otherw...
# 496429                                               passed
# 496430                                               passed
# 496431                                               passed
# 496432    \nsolucion.hs:28:1:\n    parse error (possibly...
# 496433                                               passed
# Name: result, Length: 467385, dtype: object

# %% [markdown]
# # Split Dataset
# Split dataset between train and test in 66,6 / 33,33 proportionally.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.33, random_state=42)

# %% [markdown]
# # Featurization
# DataFrameMapper is used for mapping pandas data frame columns to different sklearn transformations.

# %%
mapper = DataFrameMapper([('guide.slug', LabelEncoder()),
                         ('guide.language.name', LabelEncoder()),
                         ('content', CountVectorizer()),
                         ])

# %% [markdown]
# * X_train shape = (313147, 3)
# * X_test shape = (154238, 3)
# * Y_train shape = (313147,)
# * Y_test shape = (154238,)
#
# CountVectorizer content doesnt fit in memory :(, we need to think a better option to featurize content submissions.
