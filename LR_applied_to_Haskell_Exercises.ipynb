# %% [markdown]
# # Linear Regression applied to Haskell Exercises from "Failed_Submissions" Collection

# %% [markdown]
# In this notebook we present the results of our first approach on training a machine learning model, based on set of submissions from Haskell exercises on the Mumuki Collection ** failed_submissions** in order to automatically classify programming exercises into non executable (dark red), executable with errors (light red), correct but quality could be improved (yellow), good solution (green) .
#
# In section 1, we describe Haskell Exercise's Submissions Datasets and some filters we had make on the submissions. In section 2 we present the model we trained and the results we obtained from different excersises. Finally, in section 3 we present differents Tokenizer options for the Vectorizer, and show how they tokenize the submissions content.

# %% [markdown]
# ##  Techinical Setup

# %% [markdown]
# On the cells of this unnumbered section we define the code that it's necessary to execute to satisfy all the requirments for training the models for the differents exercises.
#
# On the code below, we install the spacy library, becuase we test different kind of Tokenizers for the Vectorizer.

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (2.0.11)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (6.10.2)
# Requirement already satisfied: ujson>=1.35 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (1.35)
# Requirement already satisfied: regex==2017.4.5 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (2017.4.5)
# Requirement already satisfied: numpy>=1.7 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (1.14.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (0.2.7.1)
# Requirement already satisfied: pathlib in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: cymem<1.32,>=1.30 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (1.31.2)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from spacy) (0.28.0)
# Requirement already satisfied: msgpack-python in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.5.6)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.8.2)
# Requirement already satisfied: termcolor in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.1.0)
# Requirement already satisfied: wrapt in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.10.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (4.23.4)
# Requirement already satisfied: msgpack-numpy==0.4.1 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.4.1)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.11.0)
# Requirement already satisfied: toolz>=0.8.0 in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy) (0.9.0)
# You are using pip version 10.0.0, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#     100% |████████████████████████████████| 37.4MB 699kB/s ta 0:00:011
# Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz in /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages
# You are using pip version 10.0.0, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/en_core_web_sm
#     -->
#     /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import numpy as np
import os
import json
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 1 The Failed Submissions Collection Dataset

# %% [markdown]
# ###  1.1The Failed Submissions Collection
#
# We decided to work with submissions that are part of the collection *failed_submissions.* Failed Sumbissions is an specific submissions collection from mumuki. The submissions that form part of this collection were made by people that are not enrolled at formal education courses. So people use directly the mumuki.io guides to learn by them self. The mumuki.io platform has guides with different programming languages. As failed_submissions collection has many submissions, we decide first to filter submission by programming language. We decide to use Haskell as programming language. Also, we decide to divide the Haskell submissions by Exercise. So we are going to have an specific dataset per exercise.

# %% [markdown]
# ### 1.2 Analize the Dataset
#
# Every submission has a field called ** status **. Depend of the code that student had submitted, the value of this field.
#
# 1.  **errored** : the code not compile.
# 2.  **failed**: the code not pass all the tests defined by the teacher.
# 3.  **passed_with_warnings**: the code pass all the tests, but on the solution the studennt is not using an specific concept that teacher ask for (expectatives)
# 4.  ** passed**: the code pass all tests and uses the concepts the teacher ask for.
# 4. ** aborted ** : server errors or code that last to much to execute.
# 5. ** pending **: we have the figure up what really do
# 6. ** manual_evaluation_pending **:  we have the figure up what really do
#
# In the code below we load the submissions per Haskell exercise to do a quantitative analysis in order to obtain status distribution by exercise.

# %%
dataset_home = 'datasets/haskell/'

submissions_df = pd.DataFrame()

for course in os.listdir('datasets/haskell/'):
    json_file = open(os.path.join(dataset_home, course), encoding='utf8')
    json_data = json.load(json_file)
    submissions = pd.io.json.json_normalize(json_data)
    submissions_df = submissions_df.append(submissions)

# %% [markdown]
# We decide to analyze the distribution of the exercises per status.  On the next table we can see the distribution of submission status by exercise. We use the *extract_metrics* function to calculate the distribution of the submissions by status.

# %%
def calculate_distribution(df, column_name, exercise):
    """
    df: Dataframe with submissions
    column_name: column with status

    Function to obtain distribution of submissions status
    return metrics and amount of submissions
    """
    total_amount_submissions = df.shape[0]
    submissions_grouped = df.groupby([column_name]).size()
    metrics = {}
    metrics = submissions_grouped
    metrics['exercise'] = str(exercise)
    metrics['submission_amount'] = total_amount_submissions
    return metrics


def weighted_mean(df, columns_to_mean, amount):
    """
    df: Dataframe with submissions
    columns_to_mean: columns to consider to be divided
    amount: pounded

    return add the weighted mean of status submission
    in the dataframe
    """
    df_mean = (df[columns_to_mean].astype(float).multiply(df[amount], axis="index")).sum()/(df[amount]).sum()
    df_mean['exercise'] = 'Weighted Mean'
    df_mean['submission_amount'] = df['submission_amount'].sum()
    df.loc[len(df)+1] = df_mean
    return df

# %%
distribution_by_exercise = pd.DataFrame(
    columns=[
        'exercise', 'submission_amount', 'aborted','errored', 'failed',
        'passed', 'passed_with_warnings', 'pending', 'running'])

exercises = submissions_df['exercise.name'].unique()

for exercise in exercises:
    df_exercise = submissions_df.where(submissions_df['exercise.name']==exercise).dropna(axis=0, how='all')
    distribution_by_exercise = (
        distribution_by_exercise.append(
            calculate_distribution(df_exercise, 'status', exercise), ignore_index=True).fillna(value=0))

#save a copy
status_by_exercises = distribution_by_exercise.drop(['aborted', 'pending','running'], axis=1, errors='ignore')

# %%
distribution_by_exercise.loc[:, 'aborted':] = distribution_by_exercise.loc[:, 'aborted':].div(distribution_by_exercise.iloc[:]['submission_amount'], axis=0)
distribution_by_exercise = weighted_mean(distribution_by_exercise, distribution_by_exercise.columns[2:], 'submission_amount')
distribution_by_exercise.sort_values('submission_amount')
# Out:
#                                      exercise  submission_amount   aborted  \
# 197          Persona con más de cuatro letras                  1  0.000000
# 115  Persona que tomó cantidad par de bebidas                  1  0.000000
# 17       Datos de una serie en base al nombre                  1  0.000000
# 184                       Bebidas alcohólicas                  3  0.000000
# 121                 ejemploDeBusquedaOrdenada                  3  0.000000
# 100                        Personas borrachas                  3  0.000000
# 119                               The numbers                  4  0.000000
# 56                                  Lo básico                  5  0.000000
# 48                              Mantenimiento                  5  0.000000
# 94                            Sobre los posts                  5  0.000000
# 65                    Quiénes están borrachos                  6  0.000000
# 22        Graduación alcohólica de una bebida                  7  0.000000
# 157                     Serie con gran elenco                  7  0.000000
# 243                             mayor y menor                  7  0.000000
# 273                          Dúo de estrellas                  8  0.000000
# 182                                inferencia                  9  0.000000
# 109                      Function composition                  9  0.000000
# 28                             Ordenar deptos                  9  0.000000
# 150          Alcohol en sangre de una persona                 10  0.000000
# 81                         ¿Cuáles series...?                 10  0.000000
# 186                                  Consulta                 10  0.000000
# 146           Datos de los que van a la disco                 11  0.000000
# 189                                   Inversa                 12  0.000000
# 45                                     Triple                 13  0.000000
# 232                                      Cubo                 13  0.000000
# 123                     Only even should pass                 16  0.000000
# 255                            cumpleBusqueda                 16  0.000000
# 89                 mailsDePersonasInteresadas                 19  0.000000
# 13          Generalizando a ap, tercera parte                 21  0.000000
# 1               Series ordenadas por criterio                 22  0.000000
# ..                                        ...                ...       ...
# 251                             Juntando todo               3734  0.008838
# 4                         cantidadTuitsCortos               3871  0.010075
# 61                               Inferencia 7               3930  0.011196
# 23                                 dispersion               4185  0.013381
# 101                           Más composición               4230  0.019858
# 248                      Cuánto paga cada uno               4257  0.011745
# 143               Un saludo superior, Parte 1               4396  0.014331
# 99                         esCuadradoPerfecto               4950  0.022626
# 169                               Composición               5077  0.014969
# 224                              Inferencia 9               5139  0.013816
# 132                              Inferencia 5               5177  0.012749
# 104                         ¡Clases de tipos!               5341  0.006553
# 267                                       mcm               5437  0.021703
# 95                                 sumarSegun               5524  0.010681
# 241                                      dias               5656  0.022100
# 42                      El plato fuerte: fold               5697  0.013340
# 111                            Recortar tuits               5877  0.015144
# 88                                      pinos               5973  0.021597
# 84                        incrementMCuadradoN               6117  0.008501
# 31                      Tipando más funciones               6328  0.008375
# 194                      Puntos Para Setenta!               6450  0.012093
# 152                            Para cerrar...               8193  0.011717
# 80                                  haceFrioF              10367  0.017749
# 7                           Tipos complicados              10463  0.014050
# 253                              esMultiploDe              11698  0.011113
# 272                       Más clases de tipos              11964  0.009194
# 50                           esMultiploDeTres              12956  0.013507
# 149                   Restricciones Múltiples              13037  0.009281
# 257                                esBisiesto              22751  0.014461
# 296                             Weighted Mean             496911  0.015323
#
#       errored    failed    passed  passed_with_warnings   pending   running
# 197  0.000000  0.000000  1.000000              0.000000  0.000000  0.000000
# 115  0.000000  0.000000  1.000000              0.000000  0.000000  0.000000
# 17   1.000000  0.000000  0.000000              0.000000  0.000000  0.000000
# 184  0.333333  0.333333  0.333333              0.000000  0.000000  0.000000
# 121  0.000000  0.000000  1.000000              0.000000  0.000000  0.000000
# 100  0.000000  0.333333  0.666667              0.000000  0.000000  0.000000
# 119  0.000000  0.000000  1.000000              0.000000  0.000000  0.000000
# 56   1.000000  0.000000  0.000000              0.000000  0.000000  0.000000
# 48   0.800000  0.000000  0.200000              0.000000  0.000000  0.000000
# 94   1.000000  0.000000  0.000000              0.000000  0.000000  0.000000
# 65   0.333333  0.166667  0.500000              0.000000  0.000000  0.000000
# 22   0.428571  0.142857  0.428571              0.000000  0.000000  0.000000
# 157  0.714286  0.000000  0.285714              0.000000  0.000000  0.000000
# 243  0.142857  0.142857  0.714286              0.000000  0.000000  0.000000
# 273  0.750000  0.000000  0.250000              0.000000  0.000000  0.000000
# 182  0.111111  0.333333  0.555556              0.000000  0.000000  0.000000
# 109  0.000000  0.333333  0.444444              0.111111  0.111111  0.000000
# 28   0.111111  0.555556  0.333333              0.000000  0.000000  0.000000
# 150  0.300000  0.300000  0.400000              0.000000  0.000000  0.000000
# 81   0.800000  0.000000  0.100000              0.100000  0.000000  0.000000
# 186  0.400000  0.000000  0.600000              0.000000  0.000000  0.000000
# 146  0.181818  0.363636  0.272727              0.181818  0.000000  0.000000
# 189  0.000000  0.166667  0.833333              0.000000  0.000000  0.000000
# 45   0.000000  0.230769  0.769231              0.000000  0.000000  0.000000
# 232  0.000000  0.230769  0.769231              0.000000  0.000000  0.000000
# 123  0.437500  0.250000  0.125000              0.187500  0.000000  0.000000
# 255  0.125000  0.562500  0.312500              0.000000  0.000000  0.000000
# 89   0.210526  0.368421  0.421053              0.000000  0.000000  0.000000
# 13   0.000000  0.000000  1.000000              0.000000  0.000000  0.000000
# 1    0.272727  0.227273  0.318182              0.181818  0.000000  0.000000
# ..        ...       ...       ...                   ...       ...       ...
# 251  0.257365  0.341725  0.190145              0.201928  0.000000  0.000000
# 4    0.146215  0.591062  0.109016              0.143115  0.000517  0.000000
# 61   0.193384  0.575064  0.208651              0.011450  0.000254  0.000000
# 23   0.525926  0.237515  0.215054              0.008124  0.000000  0.000000
# 101  0.294090  0.226478  0.385816              0.073759  0.000000  0.000000
# 248  0.295748  0.527602  0.090674              0.074231  0.000000  0.000000
# 143  0.222020  0.515014  0.240218              0.008417  0.000000  0.000000
# 99   0.309697  0.404444  0.247475              0.014141  0.001616  0.000000
# 169  0.229466  0.275162  0.409494              0.070908  0.000000  0.000000
# 224  0.118700  0.705001  0.153143              0.009340  0.000000  0.000000
# 132  0.275449  0.538729  0.158393              0.014680  0.000000  0.000000
# 104  0.558884  0.205392  0.196405              0.032765  0.000000  0.000000
# 267  0.267059  0.568144  0.141438              0.001655  0.000000  0.000000
# 95   0.171615  0.598298  0.124185              0.094135  0.001086  0.000000
# 241  0.286775  0.523868  0.133663              0.033239  0.000354  0.000000
# 42   0.211515  0.705986  0.067404              0.001580  0.000176  0.000000
# 111  0.156713  0.686234  0.079462              0.062107  0.000340  0.000000
# 88   0.450025  0.353926  0.112674              0.061611  0.000167  0.000000
# 84   0.450711  0.303417  0.109367              0.127840  0.000163  0.000000
# 31   0.269121  0.543932  0.161662              0.016909  0.000000  0.000000
# 194  0.240775  0.560310  0.088992              0.097829  0.000000  0.000000
# 152  0.453436  0.306725  0.069327              0.158672  0.000122  0.000000
# 80   0.328446  0.340889  0.131282              0.181634  0.000000  0.000000
# 7    0.186084  0.692153  0.058779              0.048648  0.000287  0.000000
# 253  0.352453  0.365533  0.196871              0.073944  0.000085  0.000000
# 272  0.387412  0.520060  0.082999              0.000334  0.000000  0.000000
# 50   0.466270  0.377123  0.141247              0.001852  0.000000  0.000000
# 149  0.204341  0.705070  0.062975              0.018332  0.000000  0.000000
# 257  0.238055  0.616237  0.084612              0.046459  0.000176  0.000000
# 296  0.252806  0.402945  0.279976              0.048602  0.000346  0.000002
#
# [296 rows x 9 columns]

# %% [markdown]
# ### 1.3 Cleaning the Datasets
#
# We're interested spcifiically in four status values: **errored **, ** failed**, ** passed_with_warnings** and ** passed **. We droped all the submissions with 'manual_pending' 'pending', 'aborted', 'running' status, because them don't provide significative data about the code and the feedback is related with server or technical problems of the Mumuki platform and they were'nt statiscally significant. We use the function * clean_submissions * to clean the dataset.
#
# On the table below we could see the results of the new status distribution of the exercises.

# %%
def clean_submissions(submissions_df, to_train=False):
    """
    submissions_df: Dataframe with submissions
    to_train: indicate if dataframe will be use for training

    Function to cleaning dataset
    """
    submissions_df = submissions_df[~(submissions_df['status'] == 'aborted')]
    submissions_df = submissions_df[~(submissions_df['status'] == 'pending')]
    submissions_df = submissions_df[~(submissions_df['status'] == 'running')]
    submissions_df = submissions_df[~(submissions_df['status'] == 'manual_evaluation_pending')]
    
    if to_train:
            submissions_df = submissions_df[submissions_df['content'] != ""]
            submissions_df = submissions_df[~submissions_df['content'].isnull()]
    return submissions_df

# %%
status_by_exercises['submission_amount'] = status_by_exercises[['errored', 'failed', 'passed', 'passed_with_warnings']].sum(axis=1)
status_by_exercises.loc[:, 'errored':'passed_with_warnings'] = status_by_exercises.loc[:, 'errored':'passed_with_warnings'].div(status_by_exercises.iloc[:]['submission_amount'], axis=0)
status_by_exercises = weighted_mean(status_by_exercises, status_by_exercises.columns[2:], 'submission_amount')
status_by_exercises.sort_values('submission_amount')
# Out:
#                                      exercise  submission_amount   errored  \
# 17       Datos de una serie en base al nombre                1.0  1.000000
# 115  Persona que tomó cantidad par de bebidas                1.0  0.000000
# 197          Persona con más de cuatro letras                1.0  0.000000
# 184                       Bebidas alcohólicas                3.0  0.333333
# 121                 ejemploDeBusquedaOrdenada                3.0  0.000000
# 100                        Personas borrachas                3.0  0.000000
# 119                               The numbers                4.0  0.000000
# 94                            Sobre los posts                5.0  1.000000
# 56                                  Lo básico                5.0  1.000000
# 48                              Mantenimiento                5.0  0.800000
# 65                    Quiénes están borrachos                6.0  0.333333
# 243                             mayor y menor                7.0  0.142857
# 157                     Serie con gran elenco                7.0  0.714286
# 22        Graduación alcohólica de una bebida                7.0  0.428571
# 273                          Dúo de estrellas                8.0  0.750000
# 109                      Function composition                8.0  0.000000
# 28                             Ordenar deptos                9.0  0.111111
# 182                                inferencia                9.0  0.111111
# 81                         ¿Cuáles series...?               10.0  0.800000
# 150          Alcohol en sangre de una persona               10.0  0.300000
# 186                                  Consulta               10.0  0.400000
# 146           Datos de los que van a la disco               11.0  0.181818
# 189                                   Inversa               12.0  0.000000
# 232                                      Cubo               13.0  0.000000
# 45                                     Triple               13.0  0.000000
# 123                     Only even should pass               16.0  0.437500
# 255                            cumpleBusqueda               16.0  0.125000
# 89                 mailsDePersonasInteresadas               19.0  0.210526
# 13          Generalizando a ap, tercera parte               21.0  0.000000
# 1               Series ordenadas por criterio               22.0  0.272727
# ..                                        ...                ...       ...
# 251                             Juntando todo             3701.0  0.259660
# 4                         cantidadTuitsCortos             3830.0  0.147781
# 61                               Inferencia 7             3885.0  0.195624
# 23                                 dispersion             4129.0  0.533059
# 101                           Más composición             4146.0  0.300048
# 248                      Cuánto paga cada uno             4207.0  0.299263
# 143               Un saludo superior, Parte 1             4333.0  0.225248
# 99                         esCuadradoPerfecto             4830.0  0.317391
# 169                               Composición             5001.0  0.232953
# 224                              Inferencia 9             5068.0  0.120363
# 132                              Inferencia 5             5111.0  0.279006
# 104                         ¡Clases de tipos!             5306.0  0.562571
# 267                                       mcm             5319.0  0.272984
# 95                                 sumarSegun             5459.0  0.173658
# 241                                      dias             5529.0  0.293362
# 42                      El plato fuerte: fold             5620.0  0.214413
# 111                            Recortar tuits             5786.0  0.159177
# 88                                      pinos             5843.0  0.460038
# 84                        incrementMCuadradoN             6064.0  0.454650
# 31                      Tipando más funciones             6275.0  0.271394
# 194                      Puntos Para Setenta!             6372.0  0.243723
# 152                            Para cerrar...             8096.0  0.458869
# 80                                  haceFrioF            10183.0  0.334381
# 7                           Tipos complicados            10313.0  0.188791
# 253                              esMultiploDe            11567.0  0.356445
# 272                       Más clases de tipos            11854.0  0.391007
# 50                           esMultiploDeTres            12781.0  0.472655
# 149                   Restricciones Múltiples            12916.0  0.206256
# 257                                esBisiesto            22418.0  0.241592
# 296                             Weighted Mean           489124.0  0.256831
#
#        failed    passed  passed_with_warnings
# 17   0.000000  0.000000              0.000000
# 115  0.000000  1.000000              0.000000
# 197  0.000000  1.000000              0.000000
# 184  0.333333  0.333333              0.000000
# 121  0.000000  1.000000              0.000000
# 100  0.333333  0.666667              0.000000
# 119  0.000000  1.000000              0.000000
# 94   0.000000  0.000000              0.000000
# 56   0.000000  0.000000              0.000000
# 48   0.000000  0.200000              0.000000
# 65   0.166667  0.500000              0.000000
# 243  0.142857  0.714286              0.000000
# 157  0.000000  0.285714              0.000000
# 22   0.142857  0.428571              0.000000
# 273  0.000000  0.250000              0.000000
# 109  0.375000  0.500000              0.125000
# 28   0.555556  0.333333              0.000000
# 182  0.333333  0.555556              0.000000
# 81   0.000000  0.100000              0.100000
# 150  0.300000  0.400000              0.000000
# 186  0.000000  0.600000              0.000000
# 146  0.363636  0.272727              0.181818
# 189  0.166667  0.833333              0.000000
# 232  0.230769  0.769231              0.000000
# 45   0.230769  0.769231              0.000000
# 123  0.250000  0.125000              0.187500
# 255  0.562500  0.312500              0.000000
# 89   0.368421  0.421053              0.000000
# 13   0.000000  1.000000              0.000000
# 1    0.227273  0.318182              0.181818
# ..        ...       ...                   ...
# 251  0.344772  0.191840              0.203729
# 4    0.597389  0.110183              0.144648
# 61   0.581725  0.211068              0.011583
# 23   0.240736  0.217970              0.008234
# 101  0.231066  0.393632              0.075253
# 248  0.533872  0.091752              0.075113
# 143  0.522502  0.243711              0.008539
# 99   0.414493  0.253623              0.014493
# 169  0.279344  0.415717              0.071986
# 224  0.714878  0.155288              0.009471
# 132  0.545686  0.160438              0.014870
# 104  0.206747  0.197701              0.032982
# 267  0.580748  0.144576              0.001692
# 95   0.605422  0.125664              0.095256
# 241  0.535902  0.136734              0.034003
# 42   0.715658  0.068327              0.001601
# 111  0.697027  0.080712              0.063083
# 88   0.361800  0.115181              0.062981
# 84   0.306069  0.110323              0.128958
# 31   0.548526  0.163028              0.017052
# 194  0.567169  0.090082              0.099027
# 152  0.310400  0.070158              0.160573
# 80   0.347049  0.133654              0.184916
# 7    0.702220  0.059633              0.049355
# 253  0.369672  0.199101              0.074782
# 272  0.524886  0.083769              0.000337
# 50   0.382286  0.143181              0.001878
# 149  0.711675  0.063565              0.018504
# 257  0.625390  0.085868              0.047150
# 296  0.409360  0.284433              0.049376
#
# [296 rows x 6 columns]

# %% [markdown]
# As we're going to use as model for training Linear Regression with a vectorizer, we have to consider some specific cases. We droped submissions with empty content because them would cause issues with vectorizer. If we consider submissions with empty conent, we have two different cases:
#
# 1. Mumuki offers some informative exercises where students  don't need to code and the content field is null. In this case when we filter the null content submissions, we will eliminate all the submissions from this particular exercise.
# 2.  In any exercises student could submit an empty solution. It's a border case that we prefer not to consider in this first approach.

# %%
#limpio submissions
submissions_df_cleaned = clean_submissions(submissions_df, to_train=True)

# %% [markdown]
# ### 1.4 Train, Dev and Test Set
#
# First of all we take a technical decistion. We decide not to train all the exercises that have less than 100 submissions. We think that we're not statiscally signifivatives.

# %%
exercises_to_train = status_by_exercises[status_by_exercises['submission_amount'] > 100].sort_values('submission_amount')[:-1]
exercises_to_train
# Out:
#                                   exercise  submission_amount   errored  \
# 225                         Descontrolarse              107.0  0.205607
# 290        validarIguales, sobre validados              120.0  0.200000
# 249                          quienesPueden              129.0  0.131783
# 127             Alcohol en Sangre con fold              131.0  0.358779
# 162           Otro alto en el camino: Data              138.0  0.000000
# 64                     positivosYNegativos              149.0  0.201342
# 112                           Pedir bebida              149.0  0.161074
# 211                             Composción              152.0  0.105263
# 148                     Funciones anónimas              152.0  0.000000
# 244                         validarIguales              165.0  0.363636
# 82                      Haciendo functores              166.0  0.620482
# 91                            estadisticas              179.0  0.256983
# 20                   ¿Cambia, todo cambia?              188.0  0.000000
# 37                               intersect              201.0  0.442786
# 266      Generalizando a ap, primera parte              202.0  0.381188
# 159  Minimo Común Múltiplo ¡Con infinitas!              203.0  0.305419
# 103                              fuePareja              217.0  0.216590
# 117                       primeroQueCumple              220.0  0.145455
# 237                                filtrar              237.0  0.185654
# 179                                aplanar              238.0  0.079832
# 166                                   head              252.0  0.119048
# 58               repetirPalabras, variante              254.0  0.263780
# 217                            elMasWinner              266.0  0.255639
# 51                         elMejorDelTramo              270.0  0.192593
# 268                         potenciasDeDos              276.0  0.242754
# 6                           cifrasBinarias              290.0  0.241379
# 8                                   filter              306.0  0.274510
# 223                    ¡Terminala! Parte 1              309.0  0.000000
# 260                            codigoUnico              313.0  0.233227
# 176   Alto en el camino: sinónimos de tipo              314.0  0.159236
# ..                                     ...                ...       ...
# 275                                 Textos             3629.0  0.148250
# 251                          Juntando todo             3701.0  0.259660
# 4                      cantidadTuitsCortos             3830.0  0.147781
# 61                            Inferencia 7             3885.0  0.195624
# 23                              dispersion             4129.0  0.533059
# 101                        Más composición             4146.0  0.300048
# 248                   Cuánto paga cada uno             4207.0  0.299263
# 143            Un saludo superior, Parte 1             4333.0  0.225248
# 99                      esCuadradoPerfecto             4830.0  0.317391
# 169                            Composición             5001.0  0.232953
# 224                           Inferencia 9             5068.0  0.120363
# 132                           Inferencia 5             5111.0  0.279006
# 104                      ¡Clases de tipos!             5306.0  0.562571
# 267                                    mcm             5319.0  0.272984
# 95                              sumarSegun             5459.0  0.173658
# 241                                   dias             5529.0  0.293362
# 42                   El plato fuerte: fold             5620.0  0.214413
# 111                         Recortar tuits             5786.0  0.159177
# 88                                   pinos             5843.0  0.460038
# 84                     incrementMCuadradoN             6064.0  0.454650
# 31                   Tipando más funciones             6275.0  0.271394
# 194                   Puntos Para Setenta!             6372.0  0.243723
# 152                         Para cerrar...             8096.0  0.458869
# 80                               haceFrioF            10183.0  0.334381
# 7                        Tipos complicados            10313.0  0.188791
# 253                           esMultiploDe            11567.0  0.356445
# 272                    Más clases de tipos            11854.0  0.391007
# 50                        esMultiploDeTres            12781.0  0.472655
# 149                Restricciones Múltiples            12916.0  0.206256
# 257                             esBisiesto            22418.0  0.241592
#
#        failed    passed  passed_with_warnings
# 225  0.598131  0.196262              0.000000
# 290  0.683333  0.083333              0.033333
# 249  0.488372  0.317829              0.062016
# 127  0.366412  0.274809              0.000000
# 162  0.000000  1.000000              0.000000
# 64   0.375839  0.395973              0.026846
# 112  0.496644  0.342282              0.000000
# 211  0.355263  0.526316              0.013158
# 148  0.000000  1.000000              0.000000
# 244  0.557576  0.072727              0.006061
# 82   0.090361  0.289157              0.000000
# 91   0.312849  0.379888              0.050279
# 20   0.000000  1.000000              0.000000
# 37   0.094527  0.378109              0.084577
# 266  0.495050  0.094059              0.029703
# 159  0.364532  0.270936              0.059113
# 103  0.631336  0.152074              0.000000
# 117  0.413636  0.436364              0.004545
# 237  0.333333  0.447257              0.033755
# 179  0.554622  0.352941              0.012605
# 166  0.444444  0.353175              0.083333
# 58   0.374016  0.279528              0.082677
# 217  0.398496  0.150376              0.195489
# 51   0.559259  0.170370              0.077778
# 268  0.416667  0.340580              0.000000
# 6    0.458621  0.251724              0.048276
# 8    0.398693  0.281046              0.045752
# 223  0.000000  1.000000              0.000000
# 260  0.623003  0.121406              0.022364
# 176  0.000000  0.824841              0.015924
# ..        ...       ...                   ...
# 275  0.497107  0.171948              0.182695
# 251  0.344772  0.191840              0.203729
# 4    0.597389  0.110183              0.144648
# 61   0.581725  0.211068              0.011583
# 23   0.240736  0.217970              0.008234
# 101  0.231066  0.393632              0.075253
# 248  0.533872  0.091752              0.075113
# 143  0.522502  0.243711              0.008539
# 99   0.414493  0.253623              0.014493
# 169  0.279344  0.415717              0.071986
# 224  0.714878  0.155288              0.009471
# 132  0.545686  0.160438              0.014870
# 104  0.206747  0.197701              0.032982
# 267  0.580748  0.144576              0.001692
# 95   0.605422  0.125664              0.095256
# 241  0.535902  0.136734              0.034003
# 42   0.715658  0.068327              0.001601
# 111  0.697027  0.080712              0.063083
# 88   0.361800  0.115181              0.062981
# 84   0.306069  0.110323              0.128958
# 31   0.548526  0.163028              0.017052
# 194  0.567169  0.090082              0.099027
# 152  0.310400  0.070158              0.160573
# 80   0.347049  0.133654              0.184916
# 7    0.702220  0.059633              0.049355
# 253  0.369672  0.199101              0.074782
# 272  0.524886  0.083769              0.000337
# 50   0.382286  0.143181              0.001878
# 149  0.711675  0.063565              0.018504
# 257  0.625390  0.085868              0.047150
#
# [246 rows x 6 columns]

# %% [markdown]
# In this particular case we decided to split the exercises dataset only in train and test. We don't use dev set because the number of submissions per exercises is small.
#
# In the code below, we can see the generation of train and test datasets for one exercise.

# %%
exercise_df = submissions_df_cleaned.where(submissions_df_cleaned['exercise.name']=='intersectar').dropna(axis=0, how='all')
X = exercise_df['content']
Y = exercise_df['status']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.40, random_state=32)

# %% [markdown]
# We try to maintain the same status distribution in train and test set as a good practice to train a machine learning model. Test and Train sets have at least one example of each status to make sure when we will train/test our model with train set it contains examples of all types of status.
#
# In the code below we show a particular exercise distribution of train and test as an example.

# %%
print("Train Distribution")
print(Y_train.value_counts()/Y_train.shape[0])

print("\n Test Distribution")
print(Y_test.value_counts()/Y_test.shape[0])
# Out:
# Train Distribution
# failed                  0.381282
# passed                  0.362218
# errored                 0.225303
# passed_with_warnings    0.031196
# Name: status, dtype: float64
#
#  Test Distribution
# failed                  0.400000
# passed                  0.314286
# errored                 0.270130
# passed_with_warnings    0.015584
# Name: status, dtype: float64

# %% [markdown]
# ## 2 Choose Model and Training
#
# We choosed Linear Regression as first approach model because is the easiest model to train. We select it as our baseline, and will try to obtain the best performance classifing submissions setting parameters and selecting tokenizer. In case that not obtain a good performance we are going to change ML model.
#
# As we describe in ** Cleaning the Dataset** section, we use *CountVectorizer* for convert submissions content into features and *LabelEncoder* to convert an status into a number. ** Status**. On this first approach the **status** will be target for our machine learning model.

# %% [markdown]
# ### 2.1 One vs Rest Algorithm
# If we train a multiclass classifier, we need to use [one-vs-rest algorithm](https://en.wikipedia.org/wiki/Multiclass_classification#One-vs.-rest). In a few words, create a binary classifier (Linear Regresssion) for each status type, classify the example by all the classifiers and get the max of those predictions as predicted label.

# %%
#Featurize submissions content
cv = CountVectorizer(lowercase=False)
X_transformed = cv.fit_transform(X_train)

#Featurize status submissions
le = LabelEncoder()
Y_transformed = le.fit_transform(Y_train)

#Train linear regression for multi label classification
lr = OneVsRestClassifier(LinearRegression())
lr.fit(X_transformed, Y_transformed)

#classify Test set
predicted = lr.predict(cv.transform(X_test))

#obtain metrics avg/total
#shape of metrics
#precision    recall  f1-score   amount_tested
metrics_by_exercise = classification_report(le.transform(Y_test), predicted, target_names=le.classes_, digits=2)

print(metrics_by_exercise)
# Out:
#                       precision    recall  f1-score   support
#
#              errored       0.88      0.14      0.25       104
#               failed       0.62      0.69      0.65       154
#               passed       0.55      0.88      0.67       121
# passed_with_warnings       0.00      0.00      0.00         6
#
#          avg / total       0.66      0.59      0.54       385

# %% [markdown]
# ### One vs Rest applied to all exercises

# %%
linear_performance = pd.DataFrame(columns=['exercise', 'precision', 'recall', 'f1-score', 'amount_tested', 'submission_amount'])
i = 0
exercises = exercises_to_train['exercise'].unique()
not_trained = []
for exercise in exercises:
    #Split dataset in train and test
    try:
        exercise_df = submissions_df_cleaned.where(submissions_df_cleaned['exercise.name']==exercise).dropna(axis=0, how='all')
        X = exercise_df['content']
        Y = exercise_df['status']

        X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.40, random_state=32)

        #Featurize submissions content
        cv = CountVectorizer(lowercase=False)
        X_transformed = cv.fit_transform(X_train)

        #Featurize status submissions
        le = LabelEncoder()
        Y_transformed = le.fit_transform(Y_train)

        #Train linear regression for multi label classification
        lr = OneVsRestClassifier(LinearRegression())
        lr.fit(X_transformed, Y_transformed)

        #classify Test set
        predicted = lr.predict(cv.transform(X_test))

        #obtain metrics avg/total
        #shape of metrics
        #precision    recall  f1-score   amount_tested
        metrics_by_exercise = classification_report(
            le.transform(Y_test), predicted, target_names=le.classes_, digits=2).split()[-4:]
        metrics_by_exercise = [str(exercise)] + metrics_by_exercise + [int(X_train.shape[0] + X_test.shape[0])]
        linear_performance.loc[len(linear_performance)+1]= metrics_by_exercise
        i += 1
    except:
        not_trained.append(exercise)
        pass
    
print("Trained {} classifier of {}".format(i, len(exercises)))
# Out:
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 3, does not match size of target_names, 4
#   .format(len(labels), len(target_names))
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/mrc/anaconda3/envs/mumuki/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Trained 220 classifier of 246

# %% [markdown]
# ### 2.2 Metrics Results
# Below we show precision recall and f1-score of classifier.

# %%
linear_performance
# Out:
#                                   exercise precision recall f1-score  \
# 1                           Descontrolarse      0.50   0.49     0.49
# 2          validarIguales, sobre validados      0.58   0.65     0.60
# 3                            quienesPueden      0.63   0.58     0.59
# 4               Alcohol en Sangre con fold      0.72   0.71     0.71
# 5                      positivosYNegativos      0.61   0.52     0.52
# 6                             Pedir bebida      0.53   0.57     0.55
# 7                               Composción      0.63   0.52     0.52
# 8                           validarIguales      0.71   0.70     0.70
# 9                       Haciendo functores      0.54   0.58     0.56
# 10                            estadisticas      0.51   0.54     0.52
# 11                               intersect      0.51   0.51     0.49
# 12       Generalizando a ap, primera parte      0.69   0.69     0.69
# 13   Minimo Común Múltiplo ¡Con infinitas!      0.53   0.52     0.50
# 14                               fuePareja      0.59   0.60     0.58
# 15                                 filtrar      0.50   0.54     0.52
# 16                                 aplanar      0.60   0.59     0.56
# 17                                    head      0.75   0.73     0.72
# 18               repetirPalabras, variante      0.56   0.55     0.54
# 19                             elMasWinner      0.71   0.68     0.69
# 20                         elMejorDelTramo      0.67   0.65     0.64
# 21                          potenciasDeDos      0.61   0.51     0.44
# 22                          cifrasBinarias      0.63   0.63     0.62
# 23                                  filter      0.64   0.60     0.60
# 24                             codigoUnico      0.56   0.64     0.59
# 25    Alto en el camino: sinónimos de tipo      0.94   0.94     0.93
# 26                              cifrasBase      0.68   0.66     0.59
# 27                        tipos-09 (remix)      0.76   0.81     0.75
# 28                   elNombreDelMejorSegun      0.67   0.71     0.69
# 29        Generalizando a ap, cuarta parte      0.56   0.58     0.55
# 30                   Multiples generadores      0.67   0.70     0.64
# ..                                     ...       ...    ...      ...
# 191                                 Textos      0.64   0.66     0.62
# 192                          Juntando todo      0.70   0.67     0.66
# 193                    cantidadTuitsCortos      0.66   0.68     0.64
# 194                           Inferencia 7      0.73   0.78     0.71
# 195                             dispersion      0.52   0.55     0.48
# 196                        Más composición      0.46   0.57     0.48
# 197                   Cuánto paga cada uno      0.50   0.55     0.48
# 198            Un saludo superior, Parte 1      0.63   0.58     0.54
# 199                     esCuadradoPerfecto      0.50   0.48     0.42
# 200                            Composición      0.59   0.64     0.61
# 201                           Inferencia 9      0.73   0.74     0.67
# 202                           Inferencia 5      0.67   0.70     0.66
# 203                      ¡Clases de tipos!      0.54   0.60     0.52
# 204                                    mcm      0.63   0.66     0.61
# 205                             sumarSegun      0.55   0.63     0.53
# 206                                   dias      0.59   0.62     0.55
# 207                  El plato fuerte: fold      0.76   0.76     0.71
# 208                         Recortar tuits      0.64   0.70     0.64
# 209                                  pinos      0.59   0.56     0.54
# 210                    incrementMCuadradoN      0.44   0.49     0.40
# 211                  Tipando más funciones      0.58   0.62     0.55
# 212                   Puntos Para Setenta!      0.63   0.63     0.55
# 213                         Para cerrar...      0.50   0.52     0.46
# 214                              haceFrioF      0.47   0.47     0.44
# 215                      Tipos complicados      0.67   0.72     0.63
# 216                           esMultiploDe      0.48   0.49     0.46
# 217                    Más clases de tipos      0.58   0.61     0.58
# 218                       esMultiploDeTres      0.52   0.52     0.49
# 219                Restricciones Múltiples      0.70   0.73     0.65
# 220                             esBisiesto      0.67   0.70     0.63
#
#     amount_tested submission_amount
# 1              43               107
# 2              48               119
# 3              52               129
# 4              52               130
# 5              60               148
# 6              60               149
# 7              61               151
# 8              66               163
# 9              66               165
# 10             72               178
# 11             80               200
# 12             81               202
# 13             81               202
# 14             87               216
# 15             95               237
# 16             96               238
# 17            101               252
# 18            102               253
# 19            106               265
# 20            108               270
# 21            110               275
# 22            116               290
# 23            122               305
# 24            125               312
# 25            124               309
# 26            127               317
# 27            132               329
# 28            136               340
# 29            138               345
# 30            143               357
# ..            ...               ...
# 191          1448              3619
# 192          1478              3693
# 193          1529              3822
# 194          1550              3875
# 195          1647              4116
# 196          1656              4138
# 197          1681              4202
# 198          1730              4323
# 199          1926              4813
# 200          1995              4987
# 201          2023              5057
# 202          2034              5083
# 203          2118              5294
# 204          2122              5303
# 205          2180              5450
# 206          2206              5514
# 207          2243              5607
# 208          2303              5756
# 209          2332              5829
# 210          2424              6060
# 211          2508              6268
# 212          2546              6363
# 213          3234              8083
# 214          4068             10170
# 215          4096             10240
# 216          4616             11540
# 217          4735             11836
# 218          5109             12771
# 219          5146             12865
# 220          8958             22395
#
# [220 rows x 6 columns]

# %%
weighted_mean(linear_performance, ['precision', 'recall', 'f1-score'],'submission_amount')
# Out:
#                                   exercise precision    recall  f1-score  \
# 1                           Descontrolarse      0.50      0.49      0.49
# 2          validarIguales, sobre validados      0.58      0.65      0.60
# 3                            quienesPueden      0.63      0.58      0.59
# 4               Alcohol en Sangre con fold      0.72      0.71      0.71
# 5                      positivosYNegativos      0.61      0.52      0.52
# 6                             Pedir bebida      0.53      0.57      0.55
# 7                               Composción      0.63      0.52      0.52
# 8                           validarIguales      0.71      0.70      0.70
# 9                       Haciendo functores      0.54      0.58      0.56
# 10                            estadisticas      0.51      0.54      0.52
# 11                               intersect      0.51      0.51      0.49
# 12       Generalizando a ap, primera parte      0.69      0.69      0.69
# 13   Minimo Común Múltiplo ¡Con infinitas!      0.53      0.52      0.50
# 14                               fuePareja      0.59      0.60      0.58
# 15                                 filtrar      0.50      0.54      0.52
# 16                                 aplanar      0.60      0.59      0.56
# 17                                    head      0.75      0.73      0.72
# 18               repetirPalabras, variante      0.56      0.55      0.54
# 19                             elMasWinner      0.71      0.68      0.69
# 20                         elMejorDelTramo      0.67      0.65      0.64
# 21                          potenciasDeDos      0.61      0.51      0.44
# 22                          cifrasBinarias      0.63      0.63      0.62
# 23                                  filter      0.64      0.60      0.60
# 24                             codigoUnico      0.56      0.64      0.59
# 25    Alto en el camino: sinónimos de tipo      0.94      0.94      0.93
# 26                              cifrasBase      0.68      0.66      0.59
# 27                        tipos-09 (remix)      0.76      0.81      0.75
# 28                   elNombreDelMejorSegun      0.67      0.71      0.69
# 29        Generalizando a ap, cuarta parte      0.56      0.58      0.55
# 30                   Multiples generadores      0.67      0.70      0.64
# ..                                     ...       ...       ...       ...
# 192                          Juntando todo      0.70      0.67      0.66
# 193                    cantidadTuitsCortos      0.66      0.68      0.64
# 194                           Inferencia 7      0.73      0.78      0.71
# 195                             dispersion      0.52      0.55      0.48
# 196                        Más composición      0.46      0.57      0.48
# 197                   Cuánto paga cada uno      0.50      0.55      0.48
# 198            Un saludo superior, Parte 1      0.63      0.58      0.54
# 199                     esCuadradoPerfecto      0.50      0.48      0.42
# 200                            Composición      0.59      0.64      0.61
# 201                           Inferencia 9      0.73      0.74      0.67
# 202                           Inferencia 5      0.67      0.70      0.66
# 203                      ¡Clases de tipos!      0.54      0.60      0.52
# 204                                    mcm      0.63      0.66      0.61
# 205                             sumarSegun      0.55      0.63      0.53
# 206                                   dias      0.59      0.62      0.55
# 207                  El plato fuerte: fold      0.76      0.76      0.71
# 208                         Recortar tuits      0.64      0.70      0.64
# 209                                  pinos      0.59      0.56      0.54
# 210                    incrementMCuadradoN      0.44      0.49      0.40
# 211                  Tipando más funciones      0.58      0.62      0.55
# 212                   Puntos Para Setenta!      0.63      0.63      0.55
# 213                         Para cerrar...      0.50      0.52      0.46
# 214                              haceFrioF      0.47      0.47      0.44
# 215                      Tipos complicados      0.67      0.72      0.63
# 216                           esMultiploDe      0.48      0.49      0.46
# 217                    Más clases de tipos      0.58      0.61      0.58
# 218                       esMultiploDeTres      0.52      0.52      0.49
# 219                Restricciones Múltiples      0.70      0.73      0.65
# 220                             esBisiesto      0.67      0.70      0.63
# 221                          Weighted Mean  0.622683  0.635714  0.586512
#
#     amount_tested submission_amount
# 1              43               107
# 2              48               119
# 3              52               129
# 4              52               130
# 5              60               148
# 6              60               149
# 7              61               151
# 8              66               163
# 9              66               165
# 10             72               178
# 11             80               200
# 12             81               202
# 13             81               202
# 14             87               216
# 15             95               237
# 16             96               238
# 17            101               252
# 18            102               253
# 19            106               265
# 20            108               270
# 21            110               275
# 22            116               290
# 23            122               305
# 24            125               312
# 25            124               309
# 26            127               317
# 27            132               329
# 28            136               340
# 29            138               345
# 30            143               357
# ..            ...               ...
# 192          1478              3693
# 193          1529              3822
# 194          1550              3875
# 195          1647              4116
# 196          1656              4138
# 197          1681              4202
# 198          1730              4323
# 199          1926              4813
# 200          1995              4987
# 201          2023              5057
# 202          2034              5083
# 203          2118              5294
# 204          2122              5303
# 205          2180              5450
# 206          2206              5514
# 207          2243              5607
# 208          2303              5756
# 209          2332              5829
# 210          2424              6060
# 211          2508              6268
# 212          2546              6363
# 213          3234              8083
# 214          4068             10170
# 215          4096             10240
# 216          4616             11540
# 217          4735             11836
# 218          5109             12771
# 219          5146             12865
# 220          8958             22395
# 221           NaN            459568
#
# [221 rows x 6 columns]

# %%
distribution_by_exercise.sort_values('submission_amount').to_csv('distribution_by_exercise.csv')

# %%
linear_performance.to_csv('linear_regression_performance.csv')
